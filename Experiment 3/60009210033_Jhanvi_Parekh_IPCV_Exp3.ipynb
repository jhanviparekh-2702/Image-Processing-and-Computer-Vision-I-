# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.25.2)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('GFG.jpg', cv2.IMREAD_COLOR)

# %%
alpha = 1.5
beta = 50
image2 = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# %%
cv2.imwrite('Brightness & contrast.jpg', image2)
# Out:
# True

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.title("Brightness & contrast")
plt.imshow(image2)

plt.show()

# %%
# Apply log transform.
c = 255/(np.log(1 + np.max(image)))
log_transformed = c * np.log(1 + image)

# Specify the data type.
log_transformed = np.array(log_transformed, dtype = np.uint8)

# Save the output.
cv2.imwrite('log_transformed.jpg', log_transformed)
# Out:
# <ipython-input-13-5dc58f9de201>:3: RuntimeWarning: divide by zero encountered in log
#   log_transformed = c * np.log(1 + image)
# <ipython-input-13-5dc58f9de201>:6: RuntimeWarning: invalid value encountered in cast
#   log_transformed = np.array(log_transformed, dtype = np.uint8)
# True

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.title("Log Transformed")
plt.imshow(log_transformed)

plt.show()

# %%
# Trying 4 gamma values.
for gamma in [0.1, 0.5, 1.2, 2.2]:

    # Apply gamma correction.
    gamma_corrected = np.array(255*(image / 255) ** gamma, dtype = 'uint8')

    # Save edited images.
    cv2.imwrite('gamma_transformed'+str(gamma)+'.jpg', gamma_corrected)

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.title("Power law Transformed")
plt.imshow(gamma_corrected)

plt.show()

# %%
image = cv2.imread('GFG1.jpg', cv2.IMREAD_COLOR)

# %%
alpha = 1.5
beta = 50
image2 = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# %%
cv2.imwrite('Brightness & contrast.jpg', image2)
# Out:
# True

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.title("Brightness & contrast")
plt.imshow(image2)

plt.show()

# %%
# Apply log transform.
c = 255/(np.log(1 + np.max(image)))
log_transformed = c * np.log(1 + image)

# Specify the data type.
log_transformed = np.array(log_transformed, dtype = np.uint8)

# Save the output.
cv2.imwrite('log_transformed.jpg', log_transformed)
# Out:
# <ipython-input-21-5dc58f9de201>:3: RuntimeWarning: divide by zero encountered in log
#   log_transformed = c * np.log(1 + image)
# <ipython-input-21-5dc58f9de201>:6: RuntimeWarning: invalid value encountered in cast
#   log_transformed = np.array(log_transformed, dtype = np.uint8)
# True

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.title("Log Transformed")
plt.imshow(log_transformed)

plt.show()

# %%
# Trying 4 gamma values.
for gamma in [0.1, 0.5, 1.2, 2.2]:

    # Apply gamma correction.
    gamma_corrected = np.array(255*(image / 255) ** gamma, dtype = 'uint8')

    # Save edited images.
    cv2.imwrite('gamma_transformed'+str(gamma)+'.jpg', gamma_corrected)

# %%
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.title("Power law Transformed")
plt.imshow(gamma_corrected)

plt.show()
